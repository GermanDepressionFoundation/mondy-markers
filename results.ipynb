# %% [markdown]
# Font: Arial
# Rohdaten train #5761AD test #000000
# Elasticnet #F2846B
# RF #9E2040

# %% [markdown]
# # RQ1

# %% [markdown]
# In **how many** of the enrolled patients with clinically diagnosed depression can analysis of their individual, up-to-one-year passive time-series data (variables described in section Data  Collection) identify  objective markers that estimate the  severity  of  depressive symptomatology as measured by daily PHQ-2 scores?

# %% [markdown]
# - 1 Dropout mit r² und rmssd --> nach r² (elastic net) nur **1** > 0.3 und mit zusätzlich rmssd fällt sogar dieser raus = **0** (rmssd nur für phq2 phq9 viele Lücken)
# - Neues Kriterium: Wir modelliren innhalb der RMSSD --> Fehelr der Prediciton MAE < RMSSD

# %% [markdown]
# ![mae_elastic_rmssd_bar.png](attachment:mae_elastic_rmssd_bar.png)

# %% [markdown]
# Varrianz und Modellierung bilden sich bei den **X** includierten Probanden wie folgt ab:

# %% [markdown]
# ![bubblypie2_elastic.png](attachment:bubblypie2_elastic.png)

# %% [markdown]
# # RQ2

# %% [markdown]
# Probanden mit MAE **+10%** > RMSSD entfernt

# %% [markdown]
# For   patients   in   whom   a   significant   linear   prediction   is   achieved,   **which**   sensor   or app-derived  data  source  contributes  most  to  the  explanation  of  individual  depression severity?

# %% [markdown]
# ![elasticnet_relative_feature_importance.png](attachment:elasticnet_relative_feature_importance.png)

# %% [markdown]
# Optional: Beispiele für individualität der Modelle und jeweils die ersten drei gewinner der porobanden einwärben/markeiren und die Verschiebung "anschaulich" aufzeigen.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# TODO: 3 Winners jeweils beim anderen Beispiel markieren / Feature nahe 0 nicht anzeigen

# %% [markdown]
# # RQ3

# %% [markdown]
# **How**  does  the  application  of  non-linear  ensemble  methods  influence  the  results  of research   questions   1   and   2?I.e., how   many   additional   patients   exhibit   a   reliable predictive pattern, and do the dominant data sources shift when non-linear relationships are allowed?

# %% [markdown]
# ### RQ3_1

# %% [markdown]
# ![mae_rf_rmssd_bar.png](attachment:mae_rf_rmssd_bar.png)

# %% [markdown]
# ### RQ3_2

# %% [markdown]
# ![randomforest_relative_feature_importance.png](attachment:randomforest_relative_feature_importance.png)

# %% [markdown]
# ![aggregated_feature_importance_relative_sorted_elastic.png](attachment:aggregated_feature_importance_relative_sorted_elastic.png)
